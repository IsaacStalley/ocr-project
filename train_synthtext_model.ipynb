# %%
DATASET_PATH = r'C:\Users\IsaacStalley\Documents\GitHub\SynthText\SynthText'

# %%
DATASET_PATH = r'C:\Users\IsaacStalley\Documents\GitHub\SynthText\SynthText'
# !python models/pytorch-ssd/train_ssd.py --dataset-type=synthtext --data=C:\Users\IsaacStalley\Documents\GitHub\SynthText\SynthText --model-dir=models/trained/synthtext --batch-size=20 --epochs=5 --workers=0
# Out:
# ^C
# c:\Users\IsaacStalley\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Traceback (most recent call last):
#   File "c:\Users\IsaacStalley\Documents\GitHub\ocr-project\models\pytorch-ssd\train_ssd.py", line 418, in <module>
#     train(train_loader, net, criterion, optimizer, device=DEVICE, debug_steps=args.debug_steps, epoch=epoch)
#   File "c:\Users\IsaacStalley\Documents\GitHub\ocr-project\models\pytorch-ssd\train_ssd.py", line 140, in train
#     for i, data in enumerate(loader):
#   File "c:\Users\IsaacStalley\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py", line 631, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
# ...

# %%
SYNTHTEXT_MODEL = "mb1-ssd-Epoch-4-Loss-9.470311237036709.pth"
IMAGE = "text.jpg"
# !python models/pytorch-ssd/run_ssd_example.py mb1-ssd models/trained/synthtext/$SYNTHTEXT_MODEL models/trained/synthtext/synthtext-labels.txt $IMAGE
